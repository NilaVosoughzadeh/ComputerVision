# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
Img = cv2.imread('panda.jpg')

# %%
cv2_imshow(Img)
# Out:
# <PIL.Image.Image image mode=RGB size=862x486>

# %%
print(Img)
# Out:
# [[[ 20  94  60]
#   [ 20  94  60]
#   [ 20  94  60]
#   ...
#   [ 25  83  54]
#   [ 25  83  54]
#   [ 26  84  55]]
#
#  [[ 19  93  59]
#   [ 19  93  59]
#   [ 19  93  59]
#   ...
#   [ 25  83  54]
#   [ 25  83  54]
#   [ 26  84  55]]
#
#  [[ 17  91  57]
#   [ 17  91  57]
#   [ 17  91  57]
#   ...
#   [ 24  84  53]
#   [ 24  84  53]
#   [ 25  85  54]]
#
#  ...
#
#  [[ 82  93 107]
#   [ 90 101 115]
#   [ 99 108 121]
#   ...
#   [ 36 115  76]
#   [ 44 126  84]
#   [ 58 140  98]]
#
#  [[ 87  98 112]
#   [ 95 106 120]
#   [104 113 126]
#   ...
#   [ 25 104  65]
#   [ 20 102  60]
#   [ 24 106  64]]
#
#  [[ 90 101 115]
#   [ 99 110 124]
#   [109 118 131]
#   ...
#   [ 12  91  52]
#   [  3  85  43]
#   [  0  80  38]]]

# %% [markdown]
# 2⁸ = 256

# %%
type(Img)
# Out:
# numpy.ndarray

# %%
print(Img.shape)
# Out:
# (486, 862, 3)

# %%
ImgRed = cv2.cvtColor(Img , cv2.COLOR_BGR2GRAY)

# %%
print(ImgRed.shape)
# Out:
# (486, 862)

# %%
cv2_imshow(ImgRed)
# Out:
# <PIL.Image.Image image mode=L size=862x486>

# %%
Img = cv2.imread('panda.jpg')

# %%
Img[100:200,100:200]=[0,0,255]
cv2_imshow(Img)
# Out:
# <PIL.Image.Image image mode=RGB size=862x486>

# %%
Img[100:,100:]=[0,0,255]

Img[200:,200:]=[0,255,0]

Img[300:,300:]=[255,0,0]

Img[400:,400:]=[255,0,255]

Img[500:,500:]=[255,255,0]

Img[600:,600:]=[0,255,255]

Img[700:,700:]=[255,255,255]

cv2_imshow(Img)
# Out:
# <PIL.Image.Image image mode=RGB size=862x486>

# %%
Img = cv2.imread('panda.jpg')

# %%
ImgCrop = Img[200:500,300:500]
cv2_imshow(ImgCrop)
# Out:
# <PIL.Image.Image image mode=RGB size=200x286>

# %%
Img = cv2.imread('panda.jpg')

# %%
ImgBlur = cv2.blur(Img,(50,50))
cv2_imshow(ImgBlur)
# Out:
# <PIL.Image.Image image mode=RGB size=862x486>

# %%
Img = cv2.imread('panda.jpg')

# %%
ImgEdge = cv2.Canny(Img,90,100)
cv2_imshow(ImgEdge)
# Out:
# <PIL.Image.Image image mode=L size=862x486>
